# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import shutil
import random
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix


def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Load the trained model
model = tf.keras.models.load_model('./model.h5')

# Path to the image you want to predict
image_path = './Original Images/Akshay Kumar/Akshay Kumar_0.jpg'

# Predict the class of the image
predicted_class = predict_image(model, image_path)
# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 
    'Hrithik Roshan_', 'Hugh Jackman_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_'
]

# Predicted class index
predicted_class_index = predict_image(model, image_path)

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# # Print the predicted class
# print("Predicted class index:", predicted_class)
# Out:
# ...
# 1/1 [==============================] - 0s 19ms/step
# Predicted class: Akshay Kumar_

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class, img

# Load the trained model
model = tf.keras.models.load_model('./model.h5')

# Path to the image you want to predict
image_path = '.\Original Images\Amitabh Bachchan\Amitabh Bachchan_1.jpg'

# Predict the class of the image
predicted_class_index, img = predict_image(model, image_path)

# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 
    'Hrithik Roshan_', 'Hugh Jackman_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_','jeewan'
]

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# Display the image with the predicted class name
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class_name}")
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 [==============================] - 0s 114ms/step
# Predicted class: Amitabh Bachchan_

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class, img

# Load the trained model
model = tf.keras.models.load_model('./model.h5')

# Path to the image you want to predict
image_path = '.\Original Images\Vijay Deverakonda\Vijay Deverakonda_0.jpg'

# Predict the class of the image
predicted_class_index, img = predict_image(model, image_path)

# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_','Alexandra Daddario_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 
    'Hrithik Roshan_', 'Hugh Jackman_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_','jeewan'
]

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# Display the image with the predicted class name
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class_name}")
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 [==============================] - 0s 111ms/step
# Predicted class: Vijay Deverakonda_

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class, img

# Load the trained model
model = tf.keras.models.load_model('./model_1.h5')

# Path to the image you want to predict
image_path = './test30/Akshay Kumar_/Akshay Kumar_1_2.jpg'

# Predict the class of the image
predicted_class_index, img = predict_image(model, image_path)

# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_','Alexandra Daddario_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 
    'Hrithik Roshan_', 'Hugh Jackman_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_','jeewan'
]

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# Display the image with the predicted class name
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class_name}")
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 [==============================] - 0s 105ms/step
# Predicted class: Akshay Kumar_

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class, img

# Load the trained model
model = tf.keras.models.load_model('./model_1.h5')

# Path to the image you want to predict
image_path = './test30/Virat Kohli_/Virat Kohli_0_5.jpg'

# Predict the class of the image
predicted_class_index, img = predict_image(model, image_path)

# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_','Alexandra Daddario_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Hrithik Roshan_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_'#,'Hugh Jackman_','jeewan'
]

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# Display the image with the predicted class name
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class_name}")
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 [==============================] - 0s 104ms/step
# Predicted class: Virat Kohli_

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
def predict_image(model, img_path, target_size=(240, 240)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    return predicted_class, img

# Load the trained model
model = tf.keras.models.load_model('./model_1.h5')

# Path to the image you want to predict
image_path = './test30/Margot Robbie_/Margot Robbie_0_1.jpg'

# Predict the class of the image
predicted_class_index, img = predict_image(model, image_path)

# List of class names
class_names = [
    'Akshay Kumar_', 'Alia Bhatt_','Alexandra Daddario_', 'Amitabh Bachchan_', 'Andy Samberg_', 'Anushka Sharma_', 
    'Billie Eilish_', 'Brad Pitt_', 'Camila Cabello_', 'Charlize Theron_', 'Claire Holt_', 
    'Hrithik Roshan_', 
    'Courtney Cox_', 'Dwayne Johnson_', 'Elizabeth Olsen_', 'Ellen Degeneres_', 'Henry Cavill_', 'Jessica Alba_', 'Lisa Kudrow_', 'Margot Robbie_', 
    'Natalie Portman_', 'Priyanka Chopra_', 'Roger Federer_', 'Tom Cruise_', 'Vijay Deverakonda_', 
    'Virat Kohli_', 'Zac Efron_'#,'Hugh Jackman_','jeewan'
]

# Get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class name
print("Predicted class:", predicted_class_name)

# Display the image with the predicted class name
plt.imshow(img)
plt.title(f"Predicted class: {predicted_class_name}")
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 [==============================] - 0s 102ms/step
# Predicted class: Margot Robbie_
